# %%
import pandas as pd
import numpy as np
import openmeteo_requests
import requests_cache
import pandas as pd
from retry_requests import retry

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://archive-api.open-meteo.com/v1/archive"
params = {
	"latitude": 43.7001,
	"longitude": -79.4163,
	"start_date": "2022-01-01",
	"end_date": "2023-12-31",
	"daily": ["weather_code", "temperature_2m_mean", "precipitation_sum", "rain_sum", "snowfall_sum", "precipitation_hours", "wind_speed_10m_max", "wind_gusts_10m_max"],
	"timezone": "America/New_York"
}
responses = openmeteo.weather_api(url, params=params)
# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process daily data. The order of variables needs to be the same as requested.
daily = response.Daily()
daily_weather_code = daily.Variables(0).ValuesAsNumpy()
daily_temperature_2m_mean = daily.Variables(1).ValuesAsNumpy()
daily_precipitation_sum = daily.Variables(2).ValuesAsNumpy()
daily_rain_sum = daily.Variables(3).ValuesAsNumpy()
daily_snowfall_sum = daily.Variables(4).ValuesAsNumpy()
daily_precipitation_hours = daily.Variables(5).ValuesAsNumpy()
daily_wind_speed_10m_max = daily.Variables(6).ValuesAsNumpy()
daily_wind_gusts_10m_max = daily.Variables(7).ValuesAsNumpy()

daily_data = {"date": pd.date_range(
	start = pd.to_datetime(daily.Time(), unit = "s", utc = True),
	end = pd.to_datetime(daily.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = daily.Interval()),
	inclusive = "left"
)}
daily_data["weather_code"] = daily_weather_code
daily_data["temperature_2m_mean"] = daily_temperature_2m_mean
daily_data["precipitation_sum"] = daily_precipitation_sum
daily_data["rain_sum"] = daily_rain_sum
daily_data["snowfall_sum"] = daily_snowfall_sum
daily_data["precipitation_hours"] = daily_precipitation_hours
daily_data["wind_speed_10m_max"] = daily_wind_speed_10m_max
daily_data["wind_gusts_10m_max"] = daily_wind_gusts_10m_max

daily_dataframe = pd.DataFrame(data = daily_data)
# Out:
# Coordinates 43.6906852722168°N -79.4117431640625°E
# Elevation 175.0 m asl
# Timezone b'America/New_York' b'EDT'
# Timezone difference to GMT+0 -14400 s

# %%
#sometimes it's more convenient to look at DFs with these settings
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

# %%
df_readme = pd.read_excel('ttc-bus-delay-data-readme.xlsx')
df_readme
# Out:
#     Field Name  \
# 0  Report Date
# 1        Route
# 2         Time
# 3          Day
# 4     Location
# 5     Incident
# 6    Min Delay
# 7      Min Gap
# 8    Direction
# 9      Vehicle
#
#                                                                                                                                                                                                                               Description  \
# 0                                                                                                                                                                          The date (YYYY/MM/DD) when the delay-causing incident occurred
# 1                                                                                                                                                                                                             The number of the bus route
# 2                                                                                                                                                                      The time (hh:mm:ss AM/PM) when the delay-causing incident occurred
# 3                                                                                                                                                                                                                     The name of the day
# 4                                                                                                                                                                                              The location of the delay-causing incident
# 5                                                                                                                                                                                           The description of the delay-causing incident
# 6                                                                                                                                                                            The delay, in minutes, to the schedule for the following bus
# 7                                                                                                                                                           The total scheduled time, in minutes, from the bus ahead of the following bus
# 8  The direction of the bus route where B,b or BW indicates both ways. (On an east west route, it includes both east and west)                                           NB - northbound, SB - southbound, EB - eastbound, WB - westbound
# 9                                                                                                                                                                                                                          Vehicle number
#
#                Example
# 0  2017-06-20 00:00:00
# 1                   51
# 2             00:35:00
# 3               Monday
# 4   York Mills Station
# 5           Mechanical
# 6                   10
# 7                   20
# 8                    N
# 9                 1057

# %%
df22 = pd.read_excel('ttc-bus-delay-data-2022.xlsx')
df23 = pd.read_excel('ttc-bus-delay-data-2023.xlsx')

# %%
df22.head(20)
# Out:
#          Date Route   Time       Day                Location  \
# 0  2022-01-01   320  02:00  Saturday        YONGE AND DUNDAS
# 1  2022-01-01   325  02:00  Saturday  OVERLEA AND THORCLIFFE
# 2  2022-01-01   320  02:00  Saturday       YONGE AND STEELES
# 3  2022-01-01   320  02:07  Saturday       YONGE AND STEELES
# 4  2022-01-01   320  02:13  Saturday       YONGE AND STEELES
# 5  2022-01-01   363  02:16  Saturday           KING AND SHAW
# 6  2022-01-01    96  02:18  Saturday         HUMBERLINE LOOP
# 7  2022-01-01   320  02:38  Saturday       STEELES AND YONGE
# 8  2022-01-01   320  02:55  Saturday       YONGE AND STEELES
# 9  2022-01-01   300  03:18  Saturday         KENNEDY STATION
# 10 2022-01-01   300  03:32  Saturday        BLOOR AND INDIAN
# 11 2022-01-01    47  03:34  Saturday  LANSDOWNE AND ST CLAIR
# 12 2022-01-01    45  03:52  Saturday   DANFORTH AND DANFORTH
# 13 2022-01-01    32  04:21  Saturday        EGLINTON STATION
# 14 2022-01-01    32  04:39  Saturday       YONGE AND BERWICK
# 15 2022-01-01    39  04:42  Saturday     FINCHDENE AND FINCH
# 16 2022-01-01    32  04:53  Saturday        RENFORTH STATION
# 17 2022-01-01    53  04:58  Saturday     STEELES AND BAYVIEW
# 18 2022-01-01    29  05:01  Saturday   DUFFERIN AND LAWRENCE
# 19 2022-01-01   334  05:02  Saturday     FINCHDENE AND FINCH
#
#                  Incident  Min Delay  Min Gap Direction  Vehicle
# 0           General Delay          0        0       NaN     8531
# 1               Diversion        131      161         W     8658
# 2   Operations - Operator         17       20         S        0
# 3   Operations - Operator          4       11         S        0
# 4   Operations - Operator          4        8         S        0
# 5   Operations - Operator         30       60       NaN        0
# 6                Security          0        0         N     3536
# 7   Operations - Operator          4        8       NaN        0
# 8   Operations - Operator          4        8       NaN        0
# 9      Emergency Services          0        0         E     8094
# 10               Security         17       34         E     8452
# 11  Operations - Operator         15       30         S        0
# 12  Operations - Operator         30       60         W     1325
# 13  Operations - Operator         16       33       NaN     1130
# 14     Emergency Services          0        0         S     1267
# 15  Operations - Operator         30       60         W        0
# 16  Operations - Operator         30        0         E     1073
# 17               Security         30       60         E     3299
# 18  Operations - Operator         10       20       NaN     9149
# 19  Operations - Operator         33        0         W     8744

# %%
df23.head(20)
# Out:
#          Date Route   Time     Day                Location  \
# 0  2023-01-01    91  02:30  Sunday   WOODBINE AND MORTIMER
# 1  2023-01-01    69  02:34  Sunday          WARDEN STATION
# 2  2023-01-01    35  03:06  Sunday            JANE STATION
# 3  2023-01-01   900  03:14  Sunday         KIPLING STATION
# 4  2023-01-01    85  03:43  Sunday          MEADOWALE LOOP
# 5  2023-01-01    40  03:47  Sunday         KIPLING STATION
# 6  2023-01-01   336  03:52  Sunday        FINCH AND ALNESS
# 7  2023-01-01    52  04:25  Sunday      LAWRENCE AND YONGE
# 8  2023-01-01    24  04:35  Sunday       DANFORTH AND MAIN
# 9  2023-01-01    36  05:18  Sunday        FINCH AND ALNESS
# 10 2023-01-01    36  05:50  Sunday           FINCH STATION
# 11 2023-01-01   300  06:04  Sunday       DANFOTH AND LOGAN
# 12 2023-01-01   320  06:07  Sunday            STEELES LOOP
# 13 2023-01-01   960  06:25  Sunday           WILSON GARAGE
# 14 2023-01-01   307  07:24  Sunday  BATHURST AND LONSMOUNT
# 15 2023-01-01    52  07:28  Sunday   LAWRENCE WEST STATION
# 16 2023-01-01    96  07:43  Sunday      YORK MILLS STATION
# 17 2023-01-01    35  07:53  Sunday            JANE STATION
# 18 2023-01-01    73  07:55  Sunday      ROYAL YORK STATION
# 19 2023-01-01   102  07:57  Sunday  MORNINGSIDE AND PASSMO
#
#                  Incident  Min Delay  Min Gap Direction  Vehicle
# 0               Diversion         81      111       NaN     8772
# 1                Security         22       44         S     8407
# 2   Cleaning - Unsanitary         30       60         N     1051
# 3                Security         17       17       NaN     3334
# 4                Security          1        1       NaN     1559
# 5      Emergency Services          0        0       NaN        0
# 6               Diversion        138      168       NaN     9220
# 7      Emergency Services         30       60         E     3520
# 8   Cleaning - Unsanitary         20       40         W     8404
# 9               Diversion        334      344       NaN     3524
# 10  Cleaning - Unsanitary         11       26         W     3561
# 11              Diversion        138      148         E     3339
# 12     Emergency Services          6       12         E     3462
# 13        Collision - TTC         11       22       NaN     8364
# 14               Security          6       12         N     8313
# 15             Mechanical         26       49       NaN     3517
# 16               Security         27       67       NaN     3623
# 17  Operations - Operator         10       20         N     1007
# 18             Mechanical         10       20         E     3350
# 19             Mechanical         20       40         N     3429

# %%
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58707 entries, 0 to 58706
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       58707 non-null  datetime64[ns]
#  1   Route      58323 non-null  object
#  2   Time       58707 non-null  object
#  3   Day        58707 non-null  object
#  4   Location   58707 non-null  object
#  5   Incident   58707 non-null  object
#  6   Min Delay  58707 non-null  int64
#  7   Min Gap    58707 non-null  int64
#  8   Direction  48227 non-null  object
#  9   Vehicle    58707 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
df23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56207 entries, 0 to 56206
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       56207 non-null  datetime64[ns]
#  1   Route      55637 non-null  object
#  2   Time       56207 non-null  object
#  3   Day        56207 non-null  object
#  4   Location   56207 non-null  object
#  5   Incident   56207 non-null  object
#  6   Min Delay  56207 non-null  int64
#  7   Min Gap    56207 non-null  int64
#  8   Direction  46667 non-null  object
#  9   Vehicle    56207 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 4.3+ MB

# %% [markdown]
# **Same columns, same formats**

# %%
df22.describe()
# Out:
#                                 Date     Min Delay       Min Gap       Vehicle
# count                          58707  58707.000000  58707.000000  58707.000000
# mean   2022-07-03 11:48:01.066993664     20.115353     32.676154   5467.459298
# min              2022-01-01 00:00:00      0.000000      0.000000      0.000000
# 25%              2022-04-06 00:00:00      9.000000     17.000000   1553.000000
# 50%              2022-07-13 00:00:00     11.000000     22.000000   7959.000000
# 75%              2022-09-27 00:00:00     20.000000     36.000000   8546.000000
# max              2022-12-31 00:00:00    999.000000    999.000000  93561.000000
# std                              NaN     48.945121     50.636856   4356.685772

# %%
df23.describe()
# Out:
#                                 Date     Min Delay       Min Gap       Vehicle
# count                          56207  56207.000000  56207.000000  56207.000000
# mean   2023-07-13 15:27:51.870051840     20.251606     32.897557   5576.547370
# min              2023-01-01 00:00:00      0.000000      0.000000      0.000000
# 25%              2023-04-15 00:00:00      9.000000     17.000000   3155.000000
# 50%              2023-07-23 00:00:00     11.000000     21.000000   7270.000000
# 75%              2023-10-12 00:00:00     20.000000     40.000000   8545.000000
# max              2023-12-31 00:00:00    998.000000    992.000000  91024.000000
# std                              NaN     50.170167     52.287433   3741.874633

# %%
[df22['Incident'].unique().size, df23['Incident'].unique().size]
# Out:
# [15, 13]

# %% [markdown]
# **Shared categories will go into ANOVA**

# %%
delay_categories_22 = list(df22['Incident'].unique())
delay_categories_23 = list(df23['Incident'].unique())
shared_categories_22_23 = list(set(delay_categories_22).intersection(set(delay_categories_23)))
not_shared_categories_22_23 = list(set(delay_categories_22).symmetric_difference(set(delay_categories_23)))
shared_categories_22_23
# Out:
# ['Collision - TTC',
#  'Cleaning - Unsanitary',
#  'Diversion',
#  'General Delay',
#  'Security',
#  'Held By',
#  'Operations - Operator',
#  'Emergency Services',
#  'Mechanical',
#  'Road Blocked - NON-TTC Collision',
#  'Vision',
#  'Investigation',
#  'Utilized Off Route']

# %% [markdown]
# **Both 'Late Entering Service' and 'Cleaning - Disinfection' have significant size in 2023, though they are not in 2022. I will create dummies for them as well**

# %%
df22[df22['Incident'] == 'Cleaning - Disinfection']
# Out:
#             Date Route   Time        Day                Location  \
# 2488  2022-01-12    47  13:41  Wednesday  CALEDONIA AND BRIDGELA
# 5138  2022-01-26   165  16:24  Wednesday      WESTON AND STEELES
# 6872  2022-02-07    34  18:31     Monday        EGLINTON STATION
# 14963 2022-04-08    52  23:48     Friday   LAWRENCE WEST STATION
# 26442 2022-06-24   168  21:10     Friday  DAVENPORT AND SYMINGTO
# 33363 2022-07-31    35  16:51     Sunday        JANE AND SHPPARD
#
#                       Incident  Min Delay  Min Gap Direction  Vehicle
# 2488   Cleaning - Disinfection        247      259         W     8368
# 5138   Cleaning - Disinfection        244      253         N     3714
# 6872   Cleaning - Disinfection          9       17         W     8790
# 14963  Cleaning - Disinfection         20       40         E     8134
# 26442  Cleaning - Disinfection          7       14       NaN     1259
# 33363  Cleaning - Disinfection          9       17         N     1056

# %%
df22[df22['Incident'] == 'Late Entering Service']
# Out:
#             Date Route   Time        Day                Location  \
# 3224  2022-01-17    95  02:28     Monday        SHEPPARD STATION
# 4586  2022-01-23    86  14:11     Sunday         KENNEDY STATION
# 5050  2022-01-26   954  06:17  Wednesday   LAWRENCE EAST STATION
# 5132  2022-01-26    36  15:37  Wednesday      FINCH WEST STATION
# 7722  2022-02-14    91  05:00     Monday        2 ALVARADO PLACE
# 9854  2022-03-01    90  05:11    Tuesday           WILSON GARAGE
# 10494 2022-03-06    80  15:08     Sunday  THE QUEENSWAY AND KIPL
# 10683 2022-03-08    98  05:28    Tuesday           WILSON GARAGE
# 11147 2022-03-11   320  01:43     Friday       YONGE AND STEELES
# 13866 2022-03-31    74  17:50   Thursday        ST CLAIR STATION
# 15600 2022-04-14    51  04:42   Thursday        EGLINTON STATION
# 15625 2022-04-14    93  06:26   Thursday   WOODBINE AND MORTIMER
# 17526 2022-04-28    72  06:58   Thursday       PAPE AND DANFORTH
# 18572 2022-05-04   924  15:04  Wednesday   VICTORIA PARK STATION
# 18815 2022-05-05    40  21:33   Thursday     DUNDAS WEST STATION
# 20710 2022-05-18    38  08:17  Wednesday       LAWSON AND WICHEY
# 21007 2022-05-20    91  14:42     Friday        WOODBINE STATION
# 21729 2022-05-26    35  10:21   Thursday            JANE STATION
# 24657 2022-06-15    86  06:27  Wednesday             TORONTO ZOO
# 25715 2022-06-21   115  06:40    Tuesday      YORK MILLS STATION
# 25918 2022-06-22   115  06:40  Wednesday      YORK MILLS STATION
# 26158 2022-06-23   115  06:40   Thursday      YORK MILLS STATION
# 26326 2022-06-24   115  06:44     Friday      YORK MILLS STATION
# 27634 2022-07-03   127  18:24     Sunday         SPADINA STATION
# 29983 2022-07-16    37  05:52   Saturday         HUMBERWOOD LOOP
# 32386 2022-07-27    97  05:19  Wednesday      YONGE AND FAIRLAWN
# 40680 2022-09-08    59  05:46   Thursday           WILSON GARAGE
# 42004 2022-09-15    63  13:37   Thursday     OAKWOOD AND VAUGHAN
# 43676 2022-09-24    86  01:21   Saturday  MEADOWVALE LOOP AND SH
# 44314 2022-09-28   167  01:39  Wednesday   PHARMACY AND MCNICOLL
# 44516 2022-09-30    68  05:11     Friday     WARDEN AND ST CLAIR
# 44637 2022-09-30    74  16:35     Friday        ST CLAIR STATION
# 44695 2022-09-30    74  17:50     Friday        ST CLAIR STATION
# 45010 2022-10-03   119  06:30     Monday          WILSON STATION
# 45653 2022-10-06    97  05:40   Thursday       HILDA AND STEELES
# 45825 2022-10-07   160  05:59     Friday          WILSON STATION
# 46513 2022-10-12   119  06:36  Wednesday          WILSON STATION
# 46778 2022-10-13    85  21:38   Thursday  SHEPPARD AND DON MILLS
# 47249 2022-10-17    54  14:35     Monday  LAWRENCE AND SCARBOROU
# 47514 2022-10-19    91  07:52  Wednesday        WOODBINE STATION
#
#                     Incident  Min Delay  Min Gap Direction  Vehicle
# 3224   Late Entering Service         14        0         E     3448
# 4586   Late Entering Service          9       18         E     3462
# 5050   Late Entering Service          8        0         E        0
# 5132   Late Entering Service         25       50       NaN     3608
# 7722   Late Entering Service         24       48         W     8655
# 9854   Late Entering Service         20       20         S     8192
# 10494  Late Entering Service         24       48         E     8070
# 10683  Late Entering Service         30       30         S     8163
# 11147  Late Entering Service         20       26         S     8354
# 13866  Late Entering Service         20       40         W     8702
# 15600  Late Entering Service         25       25         W     3156
# 15625  Late Entering Service         32       32         S     8834
# 17526  Late Entering Service         19       38         S     8419
# 18572  Late Entering Service         10       20         N     8452
# 18815  Late Entering Service         25       50         W     8012
# 20710  Late Entering Service         10       23         W     3469
# 21007  Late Entering Service          5        7         S     8857
# 21729  Late Entering Service          8       15         N     1024
# 24657  Late Entering Service         20       40         S     1660
# 25715  Late Entering Service         20       40         N     3208
# 25918  Late Entering Service         20       40         E     3312
# 26158  Late Entering Service         20       40         W     3312
# 26326  Late Entering Service         20       40         N     3129
# 27634  Late Entering Service         22       44         N     7935
# 29983  Late Entering Service         20       20         S     8090
# 32386  Late Entering Service         31       31         S     8163
# 40680  Late Entering Service         13       28         S     1374
# 42004  Late Entering Service          8       16         S     8175
# 43676  Late Entering Service         22        0         E     1606
# 44314  Late Entering Service         30       60         N     3294
# 44516  Late Entering Service         18       36         N     3201
# 44637  Late Entering Service         20       40       NaN     8769
# 44695  Late Entering Service         20       40       NaN     8846
# 45010  Late Entering Service         20       40         E     8134
# 45653  Late Entering Service         30       60         N     8204
# 45825  Late Entering Service         20       40         W     8134
# 46513  Late Entering Service         20       40         E     8392
# 46778  Late Entering Service         20       40       NaN     3444
# 47249  Late Entering Service         11       22         W     8706
# 47514  Late Entering Service         29       58         N     8767

# %%
daily_dataframe
# Out:
#                          date  weather_code  temperature_2m_mean  \
# 0   2022-01-01 04:00:00+00:00          73.0             2.319333
# 1   2022-01-02 04:00:00+00:00          73.0            -6.297333
# 2   2022-01-03 04:00:00+00:00           3.0            -9.074418
# 3   2022-01-04 04:00:00+00:00           3.0            -2.722333
# 4   2022-01-05 04:00:00+00:00          51.0             1.611000
# ..                        ...           ...                  ...
# 725 2023-12-27 04:00:00+00:00          63.0             6.240167
# 726 2023-12-28 04:00:00+00:00          53.0             6.121417
# 727 2023-12-29 04:00:00+00:00          55.0             5.406834
# 728 2023-12-30 04:00:00+00:00          51.0             0.463083
# 729 2023-12-31 04:00:00+00:00          73.0             0.008917
#
#      precipitation_sum   rain_sum  snowfall_sum  precipitation_hours  \
# 0             2.800000   0.400000          1.68                  9.0
# 1             6.000000   0.000000          4.20                 14.0
# 2             0.000000   0.000000          0.00                  0.0
# 3             0.000000   0.000000          0.00                  0.0
# 4             0.800000   0.800000          0.00                  5.0
# ..                 ...        ...           ...                  ...
# 725          20.000002  20.000002          0.00                 19.0
# 726           3.800000   3.800000          0.00                 14.0
# 727           5.800000   5.800000          0.00                 18.0
# 728           0.200000   0.200000          0.00                  2.0
# 729           2.000000   0.200000          1.26                  9.0
#
#      wind_speed_10m_max  wind_gusts_10m_max
# 0             20.907913           36.000000
# 1             22.264771           39.239998
# 2             16.981165           29.160000
# 3             21.398056           37.079998
# 4             35.221176           64.079994
# ..                  ...                 ...
# 725           17.253731           31.319998
# 726           15.790833           28.440001
# 727           15.986595           29.879999
# 728           16.965895           30.960001
# 729           13.570615           25.919998
#
# [730 rows x 9 columns]

# %% [markdown]
# What I need to do:
#
# Merge 22 and 23 into one
#
# get dummies for merged df
#
# group by days
#
# merge with weather data

# %%
merged_delays_df = pd.concat([df22, df23], ignore_index=True)

# %%
merged_delays_df[58704:58720] #to check the border
# Out:
#             Date Route   Time       Day                Location  \
# 58704 2022-12-31    72  23:56  Saturday  LOWER SHERBOURNE AND L
# 58705 2022-12-31    22  00:17  Saturday            BINGHAM LOOP
# 58706 2022-12-31     7  00:28  Saturday        BATHURST STATION
# 58707 2023-01-01    91  02:30    Sunday   WOODBINE AND MORTIMER
# 58708 2023-01-01    69  02:34    Sunday          WARDEN STATION
# 58709 2023-01-01    35  03:06    Sunday            JANE STATION
# 58710 2023-01-01   900  03:14    Sunday         KIPLING STATION
# 58711 2023-01-01    85  03:43    Sunday          MEADOWALE LOOP
# 58712 2023-01-01    40  03:47    Sunday         KIPLING STATION
# 58713 2023-01-01   336  03:52    Sunday        FINCH AND ALNESS
# 58714 2023-01-01    52  04:25    Sunday      LAWRENCE AND YONGE
# 58715 2023-01-01    24  04:35    Sunday       DANFORTH AND MAIN
# 58716 2023-01-01    36  05:18    Sunday        FINCH AND ALNESS
# 58717 2023-01-01    36  05:50    Sunday           FINCH STATION
# 58718 2023-01-01   300  06:04    Sunday       DANFOTH AND LOGAN
# 58719 2023-01-01   320  06:07    Sunday            STEELES LOOP
#
#                     Incident  Min Delay  Min Gap Direction  Vehicle
# 58704               Security         18       36         N     8493
# 58705  Cleaning - Unsanitary         10       20         S     8582
# 58706          General Delay         10       20         N     8354
# 58707              Diversion         81      111       NaN     8772
# 58708               Security         22       44         S     8407
# 58709  Cleaning - Unsanitary         30       60         N     1051
# 58710               Security         17       17       NaN     3334
# 58711               Security          1        1       NaN     1559
# 58712     Emergency Services          0        0       NaN        0
# 58713              Diversion        138      168       NaN     9220
# 58714     Emergency Services         30       60         E     3520
# 58715  Cleaning - Unsanitary         20       40         W     8404
# 58716              Diversion        334      344       NaN     3524
# 58717  Cleaning - Unsanitary         11       26         W     3561
# 58718              Diversion        138      148         E     3339
# 58719     Emergency Services          6       12         E     3462

# %%
merged_delays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114914 entries, 0 to 114913
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       114914 non-null  datetime64[ns]
#  1   Route      113960 non-null  object
#  2   Time       114914 non-null  object
#  3   Day        114914 non-null  object
#  4   Location   114914 non-null  object
#  5   Incident   114914 non-null  object
#  6   Min Delay  114914 non-null  int64
#  7   Min Gap    114914 non-null  int64
#  8   Direction  94894 non-null   object
#  9   Vehicle    114914 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 8.8+ MB

# %%
merged_df_dummies = pd.get_dummies(merged_delays_df, columns=['Incident'])

# %%
merged_df_dummies.head()
# Out:
#         Date Route   Time       Day                Location  Min Delay  \
# 0 2022-01-01   320  02:00  Saturday        YONGE AND DUNDAS          0
# 1 2022-01-01   325  02:00  Saturday  OVERLEA AND THORCLIFFE        131
# 2 2022-01-01   320  02:00  Saturday       YONGE AND STEELES         17
# 3 2022-01-01   320  02:07  Saturday       YONGE AND STEELES          4
# 4 2022-01-01   320  02:13  Saturday       YONGE AND STEELES          4
#
#    Min Gap Direction  Vehicle  Incident_Cleaning - Disinfection  ...  \
# 0        0       NaN     8531                             False  ...
# 1      161         W     8658                             False  ...
# 2       20         S        0                             False  ...
# 3       11         S        0                             False  ...
# 4        8         S        0                             False  ...
#
#    Incident_General Delay  Incident_Held By  Incident_Investigation  \
# 0                    True             False                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                   False
#
#    Incident_Late Entering Service  Incident_Mechanical  \
# 0                           False                False
# 1                           False                False
# 2                           False                False
# 3                           False                False
# 4                           False                False
#
#    Incident_Operations - Operator  Incident_Road Blocked - NON-TTC Collision  \
# 0                           False                                      False
# 1                           False                                      False
# 2                            True                                      False
# 3                            True                                      False
# 4                            True                                      False
#
#    Incident_Security  Incident_Utilized Off Route  Incident_Vision
# 0              False                        False            False
# 1              False                        False            False
# 2              False                        False            False
# 3              False                        False            False
# 4              False                        False            False
#
# [5 rows x 24 columns]

# %%
merged_df_dummies.columns
# Out:
# Index(['Date', 'Route', 'Time', 'Day', 'Location', 'Min Delay', 'Min Gap',
#        'Direction', 'Vehicle', 'Incident_Cleaning - Disinfection',
#        'Incident_Cleaning - Unsanitary', 'Incident_Collision - TTC',
#        'Incident_Diversion', 'Incident_Emergency Services',
#        'Incident_General Delay', 'Incident_Held By', 'Incident_Investigation',
#        'Incident_Late Entering Service', 'Incident_Mechanical',
#        'Incident_Operations - Operator',
#        'Incident_Road Blocked - NON-TTC Collision', 'Incident_Security',
#        'Incident_Utilized Off Route', 'Incident_Vision'],
#       dtype='object')

# %%
incident_columns = ['Incident_Cleaning - Disinfection',
       'Incident_Cleaning - Unsanitary', 'Incident_Collision - TTC',
       'Incident_Diversion', 'Incident_Emergency Services',
       'Incident_General Delay', 'Incident_Held By', 'Incident_Investigation',
       'Incident_Late Entering Service', 'Incident_Mechanical',
       'Incident_Operations - Operator',
       'Incident_Road Blocked - NON-TTC Collision', 'Incident_Security',
       'Incident_Utilized Off Route', 'Incident_Vision']

# %%
df_daily = merged_df_dummies.groupby('Date')[incident_columns].sum().reset_index()

# %%
df_daily['Total Incidents'] = df_daily[incident_columns].sum(axis=1)

# %%
merged_df = pd.concat([daily_dataframe, df_daily], axis=1)

# %%
merged_df = merged_df.rename(columns={'date': 'date_from_weather'})
merged_df
# Out:
#             date_from_weather  weather_code  temperature_2m_mean  \
# 0   2022-01-01 04:00:00+00:00          73.0             2.319333
# 1   2022-01-02 04:00:00+00:00          73.0            -6.297333
# 2   2022-01-03 04:00:00+00:00           3.0            -9.074418
# 3   2022-01-04 04:00:00+00:00           3.0            -2.722333
# 4   2022-01-05 04:00:00+00:00          51.0             1.611000
# ..                        ...           ...                  ...
# 725 2023-12-27 04:00:00+00:00          63.0             6.240167
# 726 2023-12-28 04:00:00+00:00          53.0             6.121417
# 727 2023-12-29 04:00:00+00:00          55.0             5.406834
# 728 2023-12-30 04:00:00+00:00          51.0             0.463083
# 729 2023-12-31 04:00:00+00:00          73.0             0.008917
#
#      precipitation_sum   rain_sum  snowfall_sum  precipitation_hours  \
# 0             2.800000   0.400000          1.68                  9.0
# 1             6.000000   0.000000          4.20                 14.0
# 2             0.000000   0.000000          0.00                  0.0
# 3             0.000000   0.000000          0.00                  0.0
# 4             0.800000   0.800000          0.00                  5.0
# ..                 ...        ...           ...                  ...
# 725          20.000002  20.000002          0.00                 19.0
# 726           3.800000   3.800000          0.00                 14.0
# 727           5.800000   5.800000          0.00                 18.0
# 728           0.200000   0.200000          0.00                  2.0
# 729           2.000000   0.200000          1.26                  9.0
#
#      wind_speed_10m_max  wind_gusts_10m_max       Date  ...  Incident_Held By  \
# 0             20.907913           36.000000 2022-01-01  ...                 0
# 1             22.264771           39.239998 2022-01-02  ...                 0
# 2             16.981165           29.160000 2022-01-03  ...                 0
# 3             21.398056           37.079998 2022-01-04  ...                 0
# 4             35.221176           64.079994 2022-01-05  ...                 0
# ..                  ...                 ...        ...  ...               ...
# 725           17.253731           31.319998 2023-12-27  ...                 0
# 726           15.790833           28.440001 2023-12-28  ...                 0
# 727           15.986595           29.879999 2023-12-29  ...                 0
# 728           16.965895           30.960001 2023-12-30  ...                 2
# 729           13.570615           25.919998 2023-12-31  ...                 0
#
#      Incident_Investigation  Incident_Late Entering Service  \
# 0                         1                               0
# 1                         1                               0
# 2                         4                               0
# 3                         0                               0
# 4                         1                               0
# ..                      ...                             ...
# 725                       5                               0
# 726                       1                               0
# 727                       3                               0
# 728                       5                               0
# 729                       1                               0
#
#      Incident_Mechanical  Incident_Operations - Operator  \
# 0                     21                              87
# 1                     41                              64
# 2                     55                             182
# 3                     36                             157
# 4                     48                             205
# ..                   ...                             ...
# 725                   62                              70
# 726                   55                              31
# 727                   60                              70
# 728                   65                              60
# 729                   36                              46
#
#      Incident_Road Blocked - NON-TTC Collision  Incident_Security  \
# 0                                            1                 10
# 1                                            1                  6
# 2                                            5                  3
# 3                                            1                  9
# 4                                            0                 17
# ..                                         ...                ...
# 725                                          1                 11
# 726                                          0                 13
# 727                                          1                  8
# 728                                          1                 17
# 729                                          0                 11
#
#      Incident_Utilized Off Route  Incident_Vision  Total Incidents
# 0                              7                1              144
# 1                              6                1              131
# 2                              5                0              282
# 3                              1                1              226
# 4                              6                1              298
# ..                           ...              ...              ...
# 725                            5                2              190
# 726                            1                0              143
# 727                            4                0              183
# 728                            7                4              195
# 729                           20                5              160
#
# [730 rows x 26 columns]

# %%
merged_df = merged_df.rename(columns={'Date': 'date_from_ttc'})
merged_df
# Out:
#             date_from_weather  weather_code  temperature_2m_mean  \
# 0   2022-01-01 04:00:00+00:00          73.0             2.319333
# 1   2022-01-02 04:00:00+00:00          73.0            -6.297333
# 2   2022-01-03 04:00:00+00:00           3.0            -9.074418
# 3   2022-01-04 04:00:00+00:00           3.0            -2.722333
# 4   2022-01-05 04:00:00+00:00          51.0             1.611000
# ..                        ...           ...                  ...
# 725 2023-12-27 04:00:00+00:00          63.0             6.240167
# 726 2023-12-28 04:00:00+00:00          53.0             6.121417
# 727 2023-12-29 04:00:00+00:00          55.0             5.406834
# 728 2023-12-30 04:00:00+00:00          51.0             0.463083
# 729 2023-12-31 04:00:00+00:00          73.0             0.008917
#
#      precipitation_sum   rain_sum  snowfall_sum  precipitation_hours  \
# 0             2.800000   0.400000          1.68                  9.0
# 1             6.000000   0.000000          4.20                 14.0
# 2             0.000000   0.000000          0.00                  0.0
# 3             0.000000   0.000000          0.00                  0.0
# 4             0.800000   0.800000          0.00                  5.0
# ..                 ...        ...           ...                  ...
# 725          20.000002  20.000002          0.00                 19.0
# 726           3.800000   3.800000          0.00                 14.0
# 727           5.800000   5.800000          0.00                 18.0
# 728           0.200000   0.200000          0.00                  2.0
# 729           2.000000   0.200000          1.26                  9.0
#
#      wind_speed_10m_max  wind_gusts_10m_max date_from_ttc  ...  \
# 0             20.907913           36.000000    2022-01-01  ...
# 1             22.264771           39.239998    2022-01-02  ...
# 2             16.981165           29.160000    2022-01-03  ...
# 3             21.398056           37.079998    2022-01-04  ...
# 4             35.221176           64.079994    2022-01-05  ...
# ..                  ...                 ...           ...  ...
# 725           17.253731           31.319998    2023-12-27  ...
# 726           15.790833           28.440001    2023-12-28  ...
# 727           15.986595           29.879999    2023-12-29  ...
# 728           16.965895           30.960001    2023-12-30  ...
# 729           13.570615           25.919998    2023-12-31  ...
#
#      Incident_Held By  Incident_Investigation  Incident_Late Entering Service  \
# 0                   0                       1                               0
# 1                   0                       1                               0
# 2                   0                       4                               0
# 3                   0                       0                               0
# 4                   0                       1                               0
# ..                ...                     ...                             ...
# 725                 0                       5                               0
# 726                 0                       1                               0
# 727                 0                       3                               0
# 728                 2                       5                               0
# 729                 0                       1                               0
#
#      Incident_Mechanical  Incident_Operations - Operator  \
# 0                     21                              87
# 1                     41                              64
# 2                     55                             182
# 3                     36                             157
# 4                     48                             205
# ..                   ...                             ...
# 725                   62                              70
# 726                   55                              31
# 727                   60                              70
# 728                   65                              60
# 729                   36                              46
#
#      Incident_Road Blocked - NON-TTC Collision  Incident_Security  \
# 0                                            1                 10
# 1                                            1                  6
# 2                                            5                  3
# 3                                            1                  9
# 4                                            0                 17
# ..                                         ...                ...
# 725                                          1                 11
# 726                                          0                 13
# 727                                          1                  8
# 728                                          1                 17
# 729                                          0                 11
#
#      Incident_Utilized Off Route  Incident_Vision  Total Incidents
# 0                              7                1              144
# 1                              6                1              131
# 2                              5                0              282
# 3                              1                1              226
# 4                              6                1              298
# ..                           ...              ...              ...
# 725                            5                2              190
# 726                            1                0              143
# 727                            4                0              183
# 728                            7                4              195
# 729                           20                5              160
#
# [730 rows x 26 columns]

# %%
merged_df_no_datetime = merged_df.copy()
merged_df_no_datetime['date_from_weather'] = merged_df_no_datetime['date_from_weather'].astype(str)
merged_df_no_datetime['date_from_ttc'] = merged_df_no_datetime['date_from_ttc'].astype(str)

# %%
merged_df_no_datetime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 26 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   date_from_weather                          730 non-null    object
#  1   weather_code                               730 non-null    float32
#  2   temperature_2m_mean                        730 non-null    float32
#  3   precipitation_sum                          730 non-null    float32
#  4   rain_sum                                   730 non-null    float32
#  5   snowfall_sum                               730 non-null    float32
#  6   precipitation_hours                        730 non-null    float32
#  7   wind_speed_10m_max                         730 non-null    float32
#  8   wind_gusts_10m_max                         730 non-null    float32
#  9   date_from_ttc                              730 non-null    object
#  10  Incident_Cleaning - Disinfection           730 non-null    int64
#  11  Incident_Cleaning - Unsanitary             730 non-null    int64
#  12  Incident_Collision - TTC                   730 non-null    int64
#  13  Incident_Diversion                         730 non-null    int64
#  14  Incident_Emergency Services                730 non-null    int64
#  15  Incident_General Delay                     730 non-null    int64
#  16  Incident_Held By                           730 non-null    int64
#  17  Incident_Investigation                     730 non-null    int64
#  18  Incident_Late Entering Service             730 non-null    int64
#  19  Incident_Mechanical                        730 non-null    int64
#  20  Incident_Operations - Operator             730 non-null    int64
#  21  Incident_Road Blocked - NON-TTC Collision  730 non-null    int64
#  22  Incident_Security                          730 non-null    int64
#  23  Incident_Utilized Off Route                730 non-null    int64
#  24  Incident_Vision                            730 non-null    int64
#  25  Total Incidents                            730 non-null    int64
# dtypes: float32(8), int64(16), object(2)
# memory usage: 125.6+ KB

# %%
merged_df_no_datetime.to_excel('fully_merged.xlsx')
